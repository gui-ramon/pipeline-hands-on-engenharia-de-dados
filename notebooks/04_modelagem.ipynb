# %% [markdown]
# # 04 - Modelagem
#
# Treino e avaliação de um modelo de Machine Learning a partir dos dados curados da camada Gold (`dados/gold/`).

# %%
import sys
from pathlib import Path

# Adiciona a raiz do projeto ao path para permitir o import de 'src'
sys.path.append(str(Path.cwd().parent))

from src.modelagem.modelagem import Modelagem

# %%
etapa_modelagem = Modelagem()
etapa_modelagem.executar()
